# %%
import pandas as pd
import numpy as np

# %%
titanic_train=pd.read_csv('train.csv')

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
encoded_sex_train=label_encoder.fit_transform(titanic_train["Sex"])

# %%
train1=pd.DataFrame([encoded_sex_train,titanic_train["Age"],titanic_train["Fare"]]).T

# %%
train1
# Out:
#        0     1        2
# 0    1.0  22.0   7.2500
# 1    0.0  38.0  71.2833
# 2    0.0  26.0   7.9250
# 3    0.0  35.0  53.1000
# 4    1.0  35.0   8.0500
# ..   ...   ...      ...
# 884  1.0  27.0  13.0000
# 885  0.0  19.0  30.0000
# 886  0.0  45.0  23.4500
# 887  1.0  26.0  30.0000
# 888  1.0  32.0   7.7500
#
# [889 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(X=train1,y=titanic_train['Survived'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
print("Accuracy for model using features like sex, age and fare is ",model.score(X=train1,y=titanic_train['Survived']))
# Out:
# Accuracy for model using features like sex, age and fare is  0.9763779527559056

# %%
titanic_test=pd.read_csv('test.csv')

# %%
titanic_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1305       3                            Spector, Mr. Woolf
# 413         1306       1                  Oliva y Ocana, Dona. Fermina
# 414         1307       3                  Saether, Mr. Simon Sivertsen
# 415         1308       3                           Ware, Mr. Frederick
# 416         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
titanic_test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
encoded_sex_test=label_encoder.fit_transform(titanic_test["Sex"])

# %%
test1=pd.DataFrame([encoded_sex_test,titanic_test["Age"],titanic_test["Fare"]]).T

# %%
test1
# Out:
#        0     1         2
# 0    1.0  34.5    7.8292
# 1    0.0  47.0    7.0000
# 2    1.0  62.0    9.6875
# 3    1.0  27.0    8.6625
# 4    0.0  22.0   12.2875
# ..   ...   ...       ...
# 412  1.0  45.0    8.0500
# 413  0.0  39.0  108.9000
# 414  1.0  38.5    7.2500
# 415  1.0  45.0    8.0500
# 416  1.0  45.0   22.3583
#
# [417 rows x 3 columns]

# %%
test1['Survived']=model.predict(test1)

# %%
test1
# Out:
#        0     1         2  Survived
# 0    1.0  34.5    7.8292         0
# 1    0.0  47.0    7.0000         1
# 2    1.0  62.0    9.6875         0
# 3    1.0  27.0    8.6625         1
# 4    0.0  22.0   12.2875         0
# ..   ...   ...       ...       ...
# 412  1.0  45.0    8.0500         0
# 413  0.0  39.0  108.9000         1
# 414  1.0  38.5    7.2500         0
# 415  1.0  45.0    8.0500         0
# 416  1.0  45.0   22.3583         0
#
# [417 rows x 4 columns]
